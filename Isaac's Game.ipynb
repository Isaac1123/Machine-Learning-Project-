# %% [markdown]
# ****This game is base on the scene of 'Shrek (2001)' which produced by Dreamworks Animation. https://www.imdb.com/title/tt0126029/
#
#    Once upon a time, princess Fiona has been incarcerated in the tower of the far-away mystic realm and guarded by a huge
# fire dragon for so long. Fiona hope one day she will be saved by her 'Prince Charming' and stay together for life.
# One fine day, a prince who from a neighboring kingdom passing by the odd tower and heard a softely sound as if someone is singing. After seeing this scene, it intriguing his inquisitive which lets him want to go further inside the building to figure out what's going on. However, when he close enough to the tower he realize that it's not as somple as he think, there is a princess be locked on the top of roof. Before he get there he need to complete three tricky challenge not to mention where has a dragon waiting for him....
#
# Good luck Warrior!! "A hard beginning makes a god ending"****

# %%
player_name = input(prompt= """What's your name warrior? > """)

def math_game():
            
    input("""Enter to continue""")
    print("""
    '9-3÷(1/3)+1' What's the correct answer below?
    a)1
    b)3
    c)9\n
    """)
    choice = input(">  \n")
    if "a" in choice or "1" in choice:
        input(prompt="""
        Finally, you reach to the top and facing the fire dragon;
        last step is to enter 3 times to kill the dragon
        """)
        input()
        input()
        print("""You win this game and save the princess !!!""")
        
    elif choice == "b" or "c" or"3"or"9":
        print("""Game over, Plz try again""")
        
    else:
        print("""Something goes wrong""")

def riddle_game():
                            
    input("""Enter to continue""")
    print("""
    What is as light as a feather but can't be held by anyone for long?
    a)Tissue paper
    b)A baby
    c)Your word
    d)Breath
    """)
    
    choice_1 = input(">  \n")
    
    if "d" in choice_1 or "Breath" in choice_1:
        input(prompt="""
        Finally, you reach to the top and facing the fire dragon;
        last step is to enter 3 times to kill the dragon
        """)
        input()
        input()
        print("""You win this game and save the princess !!!""")
        
    elif choice_1== "a" or "b" or "c" or "tissue" or "paper" or "baby" or "Your" or "word":
        print("""Game over, Game over, Plz try again""")
        
    else:
        print("""Something goes wrong""")

        
level_1 = input(f"""
Welcome to The Game {player_name}, plz choose Path '1' or Path '2'
> """)

if level_1 == '1':
    print("""\nIf you win Rock, Paper, Scissors then you will advance, otherwise will fail""")
    input("""Enter to continue\n""")
    
    from random import randint

    #create a list of play options

    x = ["Rock", "Paper", "Scissors"]
    
    #assign a random play to the computer
    computer = x[randint(0,2)]

    #set player to False
    player = False
    
    while player == False:
    #set player to True
    
        player = input(prompt="Rock, Paper, Scissors? > ")
        if player == computer:
            print("Tie!")
        elif player == "Rock":
            if computer == "Paper":
                print("You lose!", computer, "covers", player)
            else:
                print("You win!", player, "smashes", computer)

                level_2 = input(f"""
                Congrat {player_name} ! NOW choose Path '3' or Path '4'
                > """)            
                if level_2 =='3':
                    math_game()
                    break
                elif level_2 =='4':
                    riddle_game()
                    break
                else:
                    print("""Error message""")
                
        elif player == "Paper":
            if computer == "Scissors":
                print("You lose!", computer, "cut", player)
            else:
                print("You win!", player, "covers", computer)
                level_2 = input(f"""
                Congrat {player_name} ! NOW choose Path '3' or Path '4'
                > """)            
                if level_2 =='3':
                    math_game()
                    break
                elif level_2 =='4':
                    riddle_game()
                    break
                else:
                    print("""Error message""")
        elif player == "Scissors":
            if computer == "Rock":
                print("You lose...", computer, "smashes", player)
            else:
                print("You win!", player, "cut", computer)
                level_2 = input(f"""
                Congrat {player_name} ! NOW choose Path '3' or Path '4'
                > """)            
                if level_2 =='3':
                    math_game()
                    break
                elif level_2 =='4':
                    riddle_game()
                    break
                else:
                    print("""Error message""")
        else:
            print("That's not a valid play. Check your spelling!")
        #player was set to True, but we want it to be False so the loop continues
        player = False
        computer = x[randint(0,2)]

elif level_1 == '2':
    print("""
    \nYou will advance if you guess the right number '1~5', otherwise you will fail
    """)
    input("""Enter to continue""")
    import random
    # declaring objects
    number = random.randint(1,5) # random number remains the same for each guess
    guesses=100
    while guesses>0:
    # looping until a user is out of guesses
        choice = input('\n What is your guess (1-5)?\n >')
        choice = int(choice)

    # conditional statement based on user input
        if choice == number:
            print("\nYou win!")
            
            level_2 = input(f"""
                Congrat {player_name} ! NOW choose Path '3' or Path '4'
                > """)            
            if level_2 =='3':
                math_game()
                break
            elif level_2 =='4':
                riddle_game()
                break
            else:
                    print("""Error message""")
        elif choice != number:
            if guesses > 0:
                guesses -=1
            print("\nTry again!")
        
    # setting a different error message for inner and outer loops
        else:
            print("\nSomething went wrong.") 
    
else:
    print("""\nPlease try again""")
